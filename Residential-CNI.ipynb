# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import pmdarima as pm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
# Load the residential consumption data
RC = pd.read_csv("Residential_consumption_trends_20240901141207.csv")

# Convert 'Period start' to datetime format
RC['Period start'] = pd.to_datetime(RC['Period start'], format='%d/%m/%y')

# Filter for Central North Island (CNI) region
RC_CNI = RC[RC['Region'] == 'Central North Island']

# Split into training and validation sets by '2021-01-01'
split_date = '2021-01-01'
train_CNI = RC_CNI[RC_CNI['Period start'] < split_date]
validation_CNI = RC_CNI[RC_CNI['Period start'] >= split_date]

# Set 'Period start' as the index
train_CNI.set_index('Period start', inplace=True)
validation_CNI.set_index('Period start', inplace=True)

# Select the 'Est. Total consumption (GWh)' column as the target series for analysis
y_train = train_CNI['Est. Total consumption (GWh)']
y_validation = validation_CNI['Est. Total consumption (GWh)']

# Apply 1st order regular differencing (to remove trend)
y_train_diff = y_train.diff().dropna()

# Apply seasonal differencing (assuming monthly data, so period=12)
y_train_diff_seasonal = y_train_diff.diff(12).dropna()

# %%
# Plot ACF and PACF for the series after regular and seasonal differencing
plt.figure(figsize=(12, 6))

plt.subplot(121)
plot_acf(y_train_diff_seasonal, lags=40, ax=plt.gca())
plt.title('ACF - Regular + Seasonal Differenced Series (Training Set)')

plt.subplot(122)
plot_pacf(y_train_diff_seasonal, lags=40, ax=plt.gca())
plt.title('PACF - Regular + Seasonal Differenced Series (Training Set)')

plt.show()

# %% [markdown]
# From the differenced plot, the time series looks relatively stationary to me. So, one seasonal differencing follewed by one regular differencing is my choice before fitting the ARIMA model.

# %%
# Based on the ACF and PACF interpretation, we are building two SARIMA models: 
# 1. AR term focused model 
# 2. MA term focused model 

##########################
# Model 1: AR Term Focused
##########################
# SARIMA model with AR terms (2, 1, 0)x(1, 1, 0, 12)
sarima_model_1 = SARIMAX(y_train, order=(2, 1, 0), seasonal_order=(1, 1, 0, 12))
results_1 = sarima_model_1.fit()

# Forecast using Model 1
forecast_1 = results_1.forecast(steps=len(y_validation))

# Print the summary of Model 1
print(results_1.summary())
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.07494D+00    |proj g|=  2.96350D-02
#
# At iterate    5    f=  3.05348D+00    |proj g|=  5.36771D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      8     11      1     0     0   8.615D-06   3.053D+00
#   F =   3.0534406810410228
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:       Est. Total consumption (GWh)   No. Observations:                  132
# Model:             SARIMAX(2, 1, 0)x(1, 1, 0, 12)   Log Likelihood                -403.054
# Date:                            Thu, 03 Oct 2024   AIC                            814.108
# Time:                                    20:24:22   BIC                            825.225
# Sample:                                01-01-2010   HQIC                           818.622
#                                      - 12-01-2020
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3343      0.093     -3.604      0.000      -0.516      -0.152
# ar.L2         -0.2007      0.107     -1.868      0.062      -0.411       0.010
# ar.S.L12      -0.5093      0.085     -6.016      0.000      -0.675      -0.343
# sigma2        49.6254      5.432      9.136      0.000      38.980      60.271
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.45   Jarque-Bera (JB):                 7.38
# Prob(Q):                              0.50   Prob(JB):                         0.03
# Heteroskedasticity (H):               1.28   Skew:                            -0.30
# Prob(H) (two-sided):                  0.43   Kurtosis:                         4.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/richardpeng/anaconda3/envs/Richard/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/richardpeng/anaconda3/envs/Richard/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.

# %%
##########################
# Model 2: MA Term Focused
##########################
# SARIMA model with MA terms (0, 1, 2)x(0, 1, 1, 12)
sarima_model_2 = SARIMAX(y_train, order=(0, 1, 2), seasonal_order=(0, 1, 1, 12))
results_2 = sarima_model_2.fit()

# Forecast using Model 2
forecast_2 = results_2.forecast(steps=len(y_validation))

# Print the summary of Model 2
print(results_2.summary())
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.02235D+00    |proj g|=  9.16962D-02
#
# At iterate    5    f=  2.94590D+00    |proj g|=  2.02577D-02
#
# At iterate   10    f=  2.94506D+00    |proj g|=  1.66721D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     11     14      1     0     0   5.208D-06   2.945D+00
#   F =   2.9450555224852324
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:         Est. Total consumption (GWh)   No. Observations:                  132
# Model:             SARIMAX(0, 1, 2)x(0, 1, [1], 12)   Log Likelihood                -388.747
# Date:                              Thu, 03 Oct 2024   AIC                            785.495
# Time:                                      20:24:29   BIC                            796.611
# Sample:                                  01-01-2010   HQIC                           790.009
#                                        - 12-01-2020
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.5329      0.108     -4.923      0.000      -0.745      -0.321
# ma.L2         -0.3339      0.098     -3.393      0.001      -0.527      -0.141
# ma.S.L12      -0.6104      0.096     -6.373      0.000      -0.798      -0.423
# sigma2        37.8938      3.954      9.584      0.000      30.144      45.643
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.34   Jarque-Bera (JB):                 8.79
# Prob(Q):                              0.56   Prob(JB):                         0.01
# Heteroskedasticity (H):               1.37   Skew:                             0.45
# Prob(H) (two-sided):                  0.33   Kurtosis:                         3.98
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/richardpeng/anaconda3/envs/Richard/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/richardpeng/anaconda3/envs/Richard/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.

# %%
# SARIMA model with AR terms (2, 1, 0)x(0, 1, 1, 12)
sarima_model_3 = SARIMAX(y_train, order=(2, 1, 0), seasonal_order=(0, 1, 1, 12))
results_3 = sarima_model_3.fit()

# Forecast using Model 3
forecast_3 = results_3.forecast(steps=len(y_validation))

# Print the summary of Model 3
print(results_3.summary())
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.06401D+00    |proj g|=  9.18779D-02
#
# At iterate    5    f=  3.02032D+00    |proj g|=  2.45825D-02
#
# At iterate   10    f=  3.01142D+00    |proj g|=  1.04376D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     12     15      1     0     0   8.454D-06   3.011D+00
#   F =   3.0114148445658149
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:         Est. Total consumption (GWh)   No. Observations:                  132
# Model:             SARIMAX(2, 1, 0)x(0, 1, [1], 12)   Log Likelihood                -397.507
# Date:                              Thu, 03 Oct 2024   AIC                            803.014
# Time:                                      20:25:04   BIC                            814.130
# Sample:                                  01-01-2010   HQIC                           807.528
#                                        - 12-01-2020
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2209      0.104     -2.117      0.034      -0.425      -0.016
# ar.L2         -0.1503      0.102     -1.470      0.142      -0.351       0.050
# ma.S.L12      -0.6869      0.084     -8.144      0.000      -0.852      -0.522
# sigma2        43.7230      5.313      8.230      0.000      33.310      54.136
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.22   Jarque-Bera (JB):                 2.88
# Prob(Q):                              0.64   Prob(JB):                         0.24
# Heteroskedasticity (H):               1.34   Skew:                            -0.08
# Prob(H) (two-sided):                  0.36   Kurtosis:                         3.75
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/richardpeng/anaconda3/envs/Richard/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/richardpeng/anaconda3/envs/Richard/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.

# %%
# SARIMA model with MA terms (0, 1, 2)x(1, 1, 0, 12)
sarima_model_4 = SARIMAX(y_train, order=(0, 1, 2), seasonal_order=(1, 1, 0, 12))
results_4 = sarima_model_4.fit()

# Forecast using Model 4
forecast_4 = results_4.forecast(steps=len(y_validation))

# Print the summary of Model 2
print(results_4.summary())
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.02166D+00    |proj g|=  3.79665D-02
#
# At iterate    5    f=  2.97475D+00    |proj g|=  6.43482D-03
#
# At iterate   10    f=  2.97347D+00    |proj g|=  3.34557D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     11     13      1     0     0   2.298D-06   2.973D+00
#   F =   2.9734749687616571
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:        Est. Total consumption (GWh)   No. Observations:                  132
# Model:             SARIMAX(0, 1, 2)x(1, 1, [], 12)   Log Likelihood                -392.499
# Date:                             Thu, 03 Oct 2024   AIC                            792.997
# Time:                                     20:26:28   BIC                            804.114
# Sample:                                 01-01-2010   HQIC                           797.511
#                                       - 12-01-2020
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.5983      0.090     -6.642      0.000      -0.775      -0.422
# ma.L2         -0.2842      0.088     -3.230      0.001      -0.457      -0.112
# ar.S.L12      -0.4888      0.088     -5.528      0.000      -0.662      -0.315
# sigma2        41.1499      4.866      8.456      0.000      31.612      50.688
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.10   Jarque-Bera (JB):                 2.30
# Prob(Q):                              0.75   Prob(JB):                         0.32
# Heteroskedasticity (H):               1.32   Skew:                             0.17
# Prob(H) (two-sided):                  0.38   Kurtosis:                         3.59
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/richardpeng/anaconda3/envs/Richard/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/richardpeng/anaconda3/envs/Richard/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.

# %%
######################
# Auto ARIMA Model
######################
# Perform Auto ARIMA to automatically search for the best SARIMA model
auto_arima_model = pm.auto_arima(y_train, 
                                 seasonal=True, 
                                 m=12,  # Monthly seasonality
                                 d=1, D=1,  # Regular and seasonal differencing
                                 start_p=0, max_p=5,  # Start AR terms
                                 start_q=0, max_q=5,  # Start MA terms
                                 start_P=0, max_P=3,  # Start seasonal AR terms
                                 start_Q=0, max_Q=3,  # Start seasonal MA terms
                                 stepwise=False,  # Perform exhaustive search
                                 trace=False,  # Display search progress
                                 error_action='ignore', 
                                 suppress_warnings=True)

# Display the selected model summary
print(auto_arima_model.summary())

# Forecast using Auto ARIMA model
forecast_auto_arima = auto_arima_model.predict(n_periods=len(y_validation))
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  132
# Model:             SARIMAX(0, 1, 3)x(0, 1, [1], 12)   Log Likelihood                -385.951
# Date:                              Thu, 03 Oct 2024   AIC                            781.902
# Time:                                      20:27:11   BIC                            795.798
# Sample:                                  01-01-2010   HQIC                           787.545
#                                        - 12-01-2020
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.4061      0.113     -3.581      0.000      -0.628      -0.184
# ma.L2         -0.2503      0.109     -2.304      0.021      -0.463      -0.037
# ma.L3         -0.2227      0.114     -1.955      0.051      -0.446       0.001
# ma.S.L12      -0.6630      0.098     -6.763      0.000      -0.855      -0.471
# sigma2        35.6569      3.762      9.478      0.000      28.284      43.030
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.18   Jarque-Bera (JB):                 9.90
# Prob(Q):                              0.67   Prob(JB):                         0.01
# Heteroskedasticity (H):               1.39   Skew:                             0.44
# Prob(H) (two-sided):                  0.30   Kurtosis:                         4.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
######################
# Evaluation of Models
######################
# Function to calculate MAPE
def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Calculate MAE, RMSE, MAPE for Model 1 (AR terms)
mae_1 = mean_absolute_error(y_validation, forecast_1)
rmse_1 = np.sqrt(mean_squared_error(y_validation, forecast_1))
mape_1 = mape(y_validation, forecast_1)

# Calculate MAE, RMSE, MAPE for Model 2 (MA terms)
mae_2 = mean_absolute_error(y_validation, forecast_2)
rmse_2 = np.sqrt(mean_squared_error(y_validation, forecast_2))
mape_2 = mape(y_validation, forecast_2)

mae_3 = mean_absolute_error(y_validation, forecast_3)
rmse_3 = np.sqrt(mean_squared_error(y_validation, forecast_3))
mape_3 = mape(y_validation, forecast_3)

mae_4 = mean_absolute_error(y_validation, forecast_4)
rmse_4 = np.sqrt(mean_squared_error(y_validation, forecast_4))
mape_4 = mape(y_validation, forecast_4)

# Calculate MAE, RMSE, MAPE for Auto ARIMA model
mae_auto = mean_absolute_error(y_validation, forecast_auto_arima)
rmse_auto = np.sqrt(mean_squared_error(y_validation, forecast_auto_arima))
mape_auto = mape(y_validation, forecast_auto_arima)

# Print the evaluation results
print(f"Model 1 (AR terms) - MAE: {mae_1}, RMSE: {rmse_1}, MAPE: {mape_1}")
print(f"Model 2 (MA terms) - MAE: {mae_2}, RMSE: {rmse_2}, MAPE: {mape_2}")
print(f"Model 3 (AR terms) - MAE: {mae_3}, RMSE: {rmse_3}, MAPE: {mape_3}")
print(f"Model 4 (MA terms) - MAE: {mae_4}, RMSE: {rmse_4}, MAPE: {mape_4}")
print(f"Auto ARIMA Model - MAE: {mae_auto}, RMSE: {rmse_auto}, MAPE: {mape_auto}")
# Out:
# Model 1 (AR terms) - MAE: 6.6421533348225745, RMSE: 8.88182153801428, MAPE: 2.6719517062403697
# Model 2 (MA terms) - MAE: 6.217780429387362, RMSE: 8.743117791916472, MAPE: 2.4632396174537785
# Model 3 (AR terms) - MAE: 10.116083797986168, RMSE: 13.051369754368507, MAPE: 4.002407545226516
# Model 4 (MA terms) - MAE: 6.064058970005834, RMSE: 8.04944112961683, MAPE: 2.452917617810087
# Auto ARIMA Model - MAE: 6.713405198354879, RMSE: 9.48482045012526, MAPE: 2.62976464652032
