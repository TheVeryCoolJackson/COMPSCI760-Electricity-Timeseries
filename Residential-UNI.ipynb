# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import pmdarima as pm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
# Load the residential consumption data
RC = pd.read_csv("Residential_consumption_trends_20240901141207.csv")

# Convert 'Period start' to datetime format
RC['Period start'] = pd.to_datetime(RC['Period start'], format='%d/%m/%y')

# Filter for Upper North Island (UNI) region
RC_UNI = RC[RC['Region'] == 'Upper North Island']

# Split into training and validation sets by '2021-01-01'
split_date = '2021-01-01'
train_UNI = RC_UNI[RC_UNI['Period start'] < split_date]
validation_UNI = RC_UNI[RC_UNI['Period start'] >= split_date]

# Set 'Period start' as the index
train_UNI.set_index('Period start', inplace=True)
validation_UNI.set_index('Period start', inplace=True)

# Select the 'Est. Total consumption (GWh)' column as the target series for analysis
y_train = train_UNI['Est. Total consumption (GWh)']
y_validation = validation_UNI['Est. Total consumption (GWh)']

# Apply 1st order regular differencing (to remove trend)
y_train_diff = y_train.diff().dropna()

# Apply seasonal differencing (assuming monthly data, so period=12)
y_train_diff_seasonal = y_train_diff.diff(12).dropna()

# %%
# Plot ACF and PACF for the series after regular and seasonal differencing
plt.figure(figsize=(12, 6))

plt.subplot(121)
plot_acf(y_train_diff_seasonal, lags=40, ax=plt.gca())
plt.title('ACF - Regular + Seasonal Differenced Series (Training Set)')

plt.subplot(122)
plot_pacf(y_train_diff_seasonal, lags=40, ax=plt.gca())
plt.title('PACF - Regular + Seasonal Differenced Series (Training Set)')

plt.show()

# %%
# Based on the ACF and PACF interpretation, we are building two SARIMA models: 
# 1. AR term focused model 
# 2. MA term focused model 

##########################
# Model 1: AR Term Focused
##########################
# SARIMA model with AR terms (2, 1, 0)x(1, 1, 0, 12)
sarima_model_1 = SARIMAX(y_train, order=(2, 1, 0), seasonal_order=(1, 1, 0, 12))
results_1 = sarima_model_1.fit()

# Forecast using Model 1
forecast_1 = results_1.forecast(steps=len(y_validation))

# Print the summary of Model 1
print(results_1.summary())
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.56720D+00    |proj g|=  4.53403D-02
#
# At iterate    5    f=  3.53727D+00    |proj g|=  3.38848D-02
#
# At iterate   10    f=  3.53553D+00    |proj g|=  8.69771D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     10     13      1     0     0   8.698D-06   3.536D+00
#   F =   3.5355257180367490
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:       Est. Total consumption (GWh)   No. Observations:                  132
# Model:             SARIMAX(2, 1, 0)x(1, 1, 0, 12)   Log Likelihood                -466.689
# Date:                            Thu, 03 Oct 2024   AIC                            941.379
# Time:                                    19:55:57   BIC                            952.495
# Sample:                                01-01-2010   HQIC                           945.893
#                                      - 12-01-2020
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5161      0.085     -6.085      0.000      -0.682      -0.350
# ar.L2         -0.1284      0.112     -1.145      0.252      -0.348       0.091
# ar.S.L12      -0.5497      0.083     -6.603      0.000      -0.713      -0.387
# sigma2       143.6151     13.688     10.492      0.000     116.787     170.443
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):                20.54
# Prob(Q):                              0.82   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.65   Skew:                             0.04
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/richardpeng/anaconda3/envs/Richard/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/richardpeng/anaconda3/envs/Richard/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.

# %%
##########################
# Model 2: MA Term Focused
##########################
# SARIMA model with MA terms (0, 1, 2)x(0, 1, 1, 12)
sarima_model_2 = SARIMAX(y_train, order=(0, 1, 2), seasonal_order=(0, 1, 1, 12))
results_2 = sarima_model_2.fit()

# Forecast using Model 2
forecast_2 = results_2.forecast(steps=len(y_validation))

# Print the summary of Model 2
print(results_2.summary())
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.53750D+00    |proj g|=  8.70123D-02
#
# At iterate    5    f=  3.49811D+00    |proj g|=  3.19792D-02
#
# At iterate   10    f=  3.46540D+00    |proj g|=  1.28141D-02
#
# At iterate   15    f=  3.46232D+00    |proj g|=  3.82403D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     17     20      1     0     0   3.554D-07   3.462D+00
#   F =   3.4623184000516800
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:         Est. Total consumption (GWh)   No. Observations:                  132
# Model:             SARIMAX(0, 1, 2)x(0, 1, [1], 12)   Log Likelihood                -457.026
# Date:                              Thu, 03 Oct 2024   AIC                            922.052
# Time:                                      19:56:06   BIC                            933.169
# Sample:                                  01-01-2010   HQIC                           926.566
#                                        - 12-01-2020
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.6103      0.105     -5.806      0.000      -0.816      -0.404
# ma.L2         -0.1683      0.080     -2.103      0.035      -0.325      -0.011
# ma.S.L12      -0.7377      0.087     -8.513      0.000      -0.908      -0.568
# sigma2       116.2865     10.206     11.394      0.000      96.282     136.291
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.16   Jarque-Bera (JB):                65.74
# Prob(Q):                              0.68   Prob(JB):                         0.00
# Heteroskedasticity (H):               5.08   Skew:                             0.92
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/richardpeng/anaconda3/envs/Richard/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/richardpeng/anaconda3/envs/Richard/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.

# %%
# SARIMA model with AR terms (2, 1, 0)x(0, 1, 1, 12)
sarima_model_3 = SARIMAX(y_train, order=(2, 1, 0), seasonal_order=(0, 1, 1, 12))
results_3 = sarima_model_3.fit()

# Forecast using Model 3
forecast_3 = results_3.forecast(steps=len(y_validation))

# Print the summary of Model 3
print(results_3.summary())
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.54088D+00    |proj g|=  3.59668D-02
#
# At iterate    5    f=  3.50358D+00    |proj g|=  3.14749D-02
#
# At iterate   10    f=  3.48131D+00    |proj g|=  1.03921D-03
#
# At iterate   15    f=  3.48130D+00    |proj g|=  4.55276D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     15     18      1     0     0   4.553D-06   3.481D+00
#   F =   3.4813013059831386
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:         Est. Total consumption (GWh)   No. Observations:                  132
# Model:             SARIMAX(2, 1, 0)x(0, 1, [1], 12)   Log Likelihood                -459.532
# Date:                              Thu, 03 Oct 2024   AIC                            927.064
# Time:                                      19:56:56   BIC                            938.180
# Sample:                                  01-01-2010   HQIC                           931.578
#                                        - 12-01-2020
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4476      0.097     -4.615      0.000      -0.638      -0.258
# ar.L2         -0.0816      0.083     -0.984      0.325      -0.244       0.081
# ma.S.L12      -0.7961      0.082     -9.665      0.000      -0.958      -0.635
# sigma2       119.4704     12.516      9.545      0.000      94.939     144.002
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                10.64
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.93   Skew:                             0.22
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/richardpeng/anaconda3/envs/Richard/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/richardpeng/anaconda3/envs/Richard/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.

# %%
# SARIMA model with MA terms (0, 1, 2)x(1, 1, 0, 12)
sarima_model_4 = SARIMAX(y_train, order=(0, 1, 2), seasonal_order=(1, 1, 0, 12))
results_4 = sarima_model_4.fit()

# Forecast using Model 4
forecast_4 = results_4.forecast(steps=len(y_validation))

# Print the summary of Model 4
print(results_4.summary())
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.55860D+00    |proj g|=  7.50181D-02
#
# At iterate    5    f=  3.52582D+00    |proj g|=  1.60670D-02
#
# At iterate   10    f=  3.51358D+00    |proj g|=  1.67428D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     14     20      1     0     0   3.493D-06   3.514D+00
#   F =   3.5135555652736130
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:        Est. Total consumption (GWh)   No. Observations:                  132
# Model:             SARIMAX(0, 1, 2)x(1, 1, [], 12)   Log Likelihood                -463.789
# Date:                             Thu, 03 Oct 2024   AIC                            935.579
# Time:                                     19:58:21   BIC                            946.695
# Sample:                                 01-01-2010   HQIC                           940.093
#                                       - 12-01-2020
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.6275      0.082     -7.695      0.000      -0.787      -0.468
# ma.L2         -0.0952      0.077     -1.236      0.217      -0.246       0.056
# ar.S.L12      -0.5455      0.075     -7.284      0.000      -0.692      -0.399
# sigma2       136.3626     12.386     11.009      0.000     112.086     160.640
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                31.46
# Prob(Q):                              0.87   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.68   Skew:                             0.37
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/richardpeng/anaconda3/envs/Richard/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/richardpeng/anaconda3/envs/Richard/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.

# %%
######################
# Auto ARIMA Model
######################
# Perform Auto ARIMA to automatically search for the best SARIMA model
auto_arima_model = pm.auto_arima(y_train, 
                                 seasonal=True, 
                                 m=12,  # Monthly seasonality
                                 d=1, D=1,  # Regular and seasonal differencing
                                 start_p=0, max_p=5,  # Start AR terms
                                 start_q=0, max_q=5,  # Start MA terms
                                 start_P=0, max_P=3,  # Start seasonal AR terms
                                 start_Q=0, max_Q=3,  # Start seasonal MA terms
                                 stepwise=False,  # Perform exhaustive search
                                 trace=False,  # Display search progress
                                 error_action='ignore', 
                                 suppress_warnings=True)

# Display the selected model summary
print(auto_arima_model.summary())

# Forecast using Auto ARIMA model
forecast_auto_arima = auto_arima_model.predict(n_periods=len(y_validation))
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  132
# Model:             SARIMAX(0, 1, 3)x(0, 1, [1], 12)   Log Likelihood                -452.866
# Date:                              Thu, 03 Oct 2024   AIC                            915.733
# Time:                                      19:59:08   BIC                            929.629
# Sample:                                  01-01-2010   HQIC                           921.376
#                                        - 12-01-2020
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.5928      0.090     -6.557      0.000      -0.770      -0.416
# ma.L2          0.0058      0.077      0.075      0.940      -0.146       0.157
# ma.L3         -0.2596      0.086     -3.028      0.002      -0.428      -0.092
# ma.S.L12      -0.7765      0.085     -9.136      0.000      -0.943      -0.610
# sigma2       106.3822     10.337     10.292      0.000      86.123     126.642
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                39.68
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.61   Skew:                             0.75
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.39
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
######################
# Evaluation of Models
######################
# Function to calculate MAPE
def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Calculate MAE, RMSE, MAPE for Model 1 (AR terms)
mae_1 = mean_absolute_error(y_validation, forecast_1)
rmse_1 = np.sqrt(mean_squared_error(y_validation, forecast_1))
mape_1 = mape(y_validation, forecast_1)

# Calculate MAE, RMSE, MAPE for Model 2 (MA terms)
mae_2 = mean_absolute_error(y_validation, forecast_2)
rmse_2 = np.sqrt(mean_squared_error(y_validation, forecast_2))
mape_2 = mape(y_validation, forecast_2)

mae_3 = mean_absolute_error(y_validation, forecast_3)
rmse_3 = np.sqrt(mean_squared_error(y_validation, forecast_3))
mape_3 = mape(y_validation, forecast_3)

mae_4 = mean_absolute_error(y_validation, forecast_4)
rmse_4 = np.sqrt(mean_squared_error(y_validation, forecast_4))
mape_4 = mape(y_validation, forecast_4)

# Calculate MAE, RMSE, MAPE for Auto ARIMA model
mae_auto = mean_absolute_error(y_validation, forecast_auto_arima)
rmse_auto = np.sqrt(mean_squared_error(y_validation, forecast_auto_arima))
mape_auto = mape(y_validation, forecast_auto_arima)

# Print the evaluation results
print(f"Model 1 (AR terms) - MAE: {mae_1}, RMSE: {rmse_1}, MAPE: {mape_1}")
print(f"Model 2 (MA terms) - MAE: {mae_2}, RMSE: {rmse_2}, MAPE: {mape_2}")
print(f"Model 3 (AR terms) - MAE: {mae_3}, RMSE: {rmse_3}, MAPE: {mape_3}")
print(f"Model 4 (MA terms) - MAE: {mae_4}, RMSE: {rmse_4}, MAPE: {mape_4}")
print(f"Auto ARIMA Model - MAE: {mae_auto}, RMSE: {rmse_auto}, MAPE: {mape_auto}")
# Out:
# Model 1 (AR terms) - MAE: 18.445422772302674, RMSE: 22.594342562661854, MAPE: 4.822578252463808
# Model 2 (MA terms) - MAE: 15.541211547097921, RMSE: 20.457364846282104, MAPE: 3.9546526446562114
# Model 3 (AR terms) - MAE: 24.086612922554952, RMSE: 29.091804379755747, MAPE: 6.161492924800387
# Model 4 (MA terms) - MAE: 15.775928569578735, RMSE: 19.17933084242624, MAPE: 4.100672265251705
# Auto ARIMA Model - MAE: 15.72558232269619, RMSE: 20.880236051990146, MAPE: 3.9867155442064677
